# %%
import csv
print("Program to demonstrate csv.reader() function:")
print("\n")
# Out:
# Program to demonstrate csv.reader() function:

# %%
file_read = open('/Users/pedroaltamirano/Downloads/contactos_servigraf.csv','r')
print("The csv file is opened for reading:")
print("\n")
file_open = csv.reader(file_read)
print("The contents of the above file is as follows:")

contactos = []
for row in file_open:
  contactos.append({
    'empresa_id':	1709636664001,
    'usuario_id':	1709636664,
    'cliente_empresa_id':	None,
    'actividad':	'imprenta',
    'titulo':	row[4],
    'nombre':	row[5],
    'apellido':	row[6],
    'cargo':	'gerente',
    'direccion':	row[8],
    'sector':	row[9],
    'celular':	row[10],
    'telefono':	row[11],
    'extencion':	row[12],
    'email':	row[13],
    'web': row[14],
  })

print(contactos)

c.close()
# Out:
# The csv file is opened for reading:
#
#
# The contents of the above file is as follows:
# [{'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'titulo', 'nombre': 'nombre', 'apellido': 'apellido', 'cargo': 'gerente', 'direccion': 'direccion', 'sector': 'sector', 'celular': 'celular', 'telefono': 'telefono', 'extencion': 'extencion', 'email': 'email', 'web': 'web'}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Javier', 'apellido': 'Vasquez', 'cargo': 'gerente', 'direccion': 'Uruguay 367 y Bogotá', 'sector': '', 'celular': '987654321', 'telefono': '22906472', 'extencion': '', 'email': 'imprexiones@hotmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Samuel', 'apellido': 'Altamirano', 'cargo': 'gerente', 'direccion': 'Machala N65-40 y Libertador', 'sector': 'cotocollao', 'celular': '984597193', 'telefono': '25143236', 'extencion': '1111', 'email': 'samuel_ap@hotmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': '--', 'apellido': '--', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '987654321', 'telefono': '', 'extencion': '', 'email': 'info@servigraf.me', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Daniel', 'apellido': 'Morales', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '985405023', 'telefono': '', 'extencion': '', 'email': 'mofredd@hotmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Sasha', 'apellido': 'Montero', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '993673055', 'telefono': '123456789', 'extencion': '', 'email': 'domegraphic@gmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Arturo ', 'apellido': 'Erazo', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '991659516', 'telefono': '', 'extencion': '', 'email': 'solo@gmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Patricia', 'apellido': 'Lopez', 'cargo': 'gerente', 'direccion': 'Uruguay N16-66 y Río de Janeiro', 'sector': '', 'celular': '987620452', 'telefono': '22294113', 'extencion': '', 'email': 'mayerling_lc@imprenta-grafos.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Sandy ', 'apellido': 'Altamirano', 'cargo': 'gerente', 'direccion': 'Av. 6 de diciembre', 'sector': '', 'celular': '979329161', 'telefono': '22466810', 'extencion': '', 'email': 'intercopy773@gmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Daniel', 'apellido': 'Palacios', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '995572192', 'telefono': '', 'extencion': '', 'email': 'kaligrafpalacios@roketmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Daniel ', 'apellido': 'Altamirano', 'cargo': 'gerente', 'direccion': '', 'sector': '', 'celular': '992809880', 'telefono': '', 'extencion': '', 'email': 'danielapi63@gmail.com', 'web': ''}, {'empresa_id': 1709636664001, 'usuario_id': 1709636664, 'cliente_empresa_id': None, 'actividad': 'imprenta', 'titulo': 'Sr.', 'nombre': 'Juan Carlos', 'apellido': 'Castillo', 'cargo': 'gerente', 'direccion': 'Uruguay y Buenos Aires', 'sector': '', 'celular': '9614 ...
